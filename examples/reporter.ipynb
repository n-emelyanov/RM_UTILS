# %% [markdown]
# # Смена директории

# %%
# %cd ..
# Out:
# /Users/uzumnasiya/Work/RM_UTILS

# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd
from rm_utils.reports.reporter import ExcelReporter

# %%
path = r'examples/data/report.xlsx'
writer = ExcelReporter(path)
# Out:
# ['Sheet']

# %%
data = pd.DataFrame(
    {
        "Name": ["John", "Alice", "Bob"],
        "Age": [25, 30, 35],
        "City": ["New York", "London", "Paris"],
    }
)

data
# Out:
#     Name  Age      City
# 0   John   25  New York
# 1  Alice   30    London
# 2    Bob   35     Paris

# %%
writer.add_dataframe(data, row_offset=5, col_offset=2)

# %%
writer.save()
